# %% [markdown]
# <a href="https://colab.research.google.com/github/datametal/gretel-synthetic-data/blob/main/bike_dataset_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --pre pycaret

# %%
import pycaret
pycaret.__version__
# Out:
# '3.0.0.rc8'

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/gretelai/gdpr-helpers/main/data/adventure-works-bike-buying.csv')

# %%
data.shape
# Out:
# (16519, 24)

# %%
data.dtypes
# Out:
# CustomerID               int64
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# Suffix                  object
# AddressLine1            object
# AddressLine2            object
# City                    object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# PhoneNumber             object
# BirthDate               object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag            int64
# NumberCarsOwned          int64
# NumberChildrenAtHome     int64
# TotalChildren            int64
# YearlyIncome             int64
# BikeBuyer                int64
# dtype: object

# %%
data.head()
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
#
#           AddressLine1 AddressLine2         City StateProvinceName  ...  \
# 0      3761 N. 14th St          NaN  Rockhampton        Queensland  ...
# 1           2243 W St.          NaN      Seaford          Victoria  ...
# 2     5844 Linden Land          NaN       Hobart          Tasmania  ...
# 3     1825 Village Pl.          NaN   North Ryde   New South Wales  ...
# 4  7553 Harness Circle          NaN   Wollongong   New South Wales  ...
#
#     Education    Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0  Bachelors   Professional      M             M             1
# 1  Bachelors   Professional      M             S             0
# 2  Bachelors   Professional      M             M             1
# 3  Bachelors   Professional      F             S             0
# 4  Bachelors   Professional      F             S             1
#
#   NumberCarsOwned NumberChildrenAtHome TotalChildren  YearlyIncome  BikeBuyer
# 0               0                    0             2        137947          0
# 1               1                    3             3        101141          1
# 2               1                    3             3         91945          0
# 3               1                    0             0         86688          0
# 4               4                    5             5         92771          1
#
# [5 rows x 24 columns]

# %%
data.isnull().sum()
# Out:
# CustomerID                  0
# Title                   16431
# FirstName                   0
# MiddleName               6985
# LastName                    0
# Suffix                  16517
# AddressLine1                0
# AddressLine2            16243
# City                        0
# StateProvinceName           0
# CountryRegionName           0
# PostalCode                  0
# PhoneNumber                 0
# BirthDate                   0
# Education                   0
# Occupation                  0
# Gender                      0
# MaritalStatus               0
# HomeOwnerFlag               0
# NumberCarsOwned             0
# NumberChildrenAtHome        0
# TotalChildren               0
# YearlyIncome                0
# BikeBuyer                   0
# dtype: int64

# %%
data.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'BikeBuyer'],
#       dtype='object')

# %%
data['BirthDate'] = pd.to_datetime(data['BirthDate'])

# %%
from pycaret.classification import *
s = setup(data, target = 'BikeBuyer', session_id = 123,
          ignore_features = ['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2', 'PhoneNumber'],
          numeric_features = ['TotalChildren', 'NumberChildrenAtHome', 'NumberCarsOwned', 'HomeOwnerFlag', 'YearlyIncome'],
          categorical_features = ['City', 'StateProvinceName', 'CountryRegionName', 'Education', 'Occupation', 'Gender', 'MaritalStatus', 'PostalCode'],
          date_features = ['BirthDate'],
          max_encoding_ohe=20)
# Out:
# <style type="text/css">
# #T_c4279_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c4279_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4279_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4279_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c4279_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4279_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c4279_row1_col1" class="data row1 col1" >BikeBuyer</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4279_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c4279_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4279_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c4279_row3_col1" class="data row3 col1" >(16519, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4279_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c4279_row4_col1" class="data row4 col1" >(16519, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c4279_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c4279_row5_col1" class="data row5 col1" >(11563, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c4279_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c4279_row6_col1" class="data row6 col1" >(4956, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c4279_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_c4279_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c4279_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_c4279_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c4279_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_c4279_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c4279_row10_col0" class="data row10 col0" >Date features</td>
#       <td id="T_c4279_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c4279_row11_col0" class="data row11 col0" >Categorical features</td>
#       <td id="T_c4279_row11_col1" class="data row11 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c4279_row12_col0" class="data row12 col0" >Rows with missing values</td>
#       <td id="T_c4279_row12_col1" class="data row12 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c4279_row13_col0" class="data row13 col0" >Preprocess</td>
#       <td id="T_c4279_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c4279_row14_col0" class="data row14 col0" >Imputation type</td>
#       <td id="T_c4279_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c4279_row15_col0" class="data row15 col0" >Numeric imputation</td>
#       <td id="T_c4279_row15_col1" class="data row15 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c4279_row16_col0" class="data row16 col0" >Categorical imputation</td>
#       <td id="T_c4279_row16_col1" class="data row16 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c4279_row17_col0" class="data row17 col0" >Maximum one-hot encoding</td>
#       <td id="T_c4279_row17_col1" class="data row17 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c4279_row18_col0" class="data row18 col0" >Encoding method</td>
#       <td id="T_c4279_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c4279_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_c4279_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c4279_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_c4279_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c4279_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_c4279_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c4279_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_c4279_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c4279_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_c4279_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_c4279_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_c4279_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c4279_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_c4279_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_c4279_row25_col1" class="data row25 col1" >2db7</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%time
best = compare_models()
# Out:
# <style type="text/css">
# #T_3bb01_ th {
#   text-align: left;
# }
# #T_3bb01_row0_col0, #T_3bb01_row0_col3, #T_3bb01_row0_col4, #T_3bb01_row0_col5, #T_3bb01_row1_col0, #T_3bb01_row1_col1, #T_3bb01_row1_col2, #T_3bb01_row1_col3, #T_3bb01_row1_col4, #T_3bb01_row1_col5, #T_3bb01_row1_col6, #T_3bb01_row1_col7, #T_3bb01_row2_col0, #T_3bb01_row2_col1, #T_3bb01_row2_col2, #T_3bb01_row2_col3, #T_3bb01_row2_col4, #T_3bb01_row2_col6, #T_3bb01_row2_col7, #T_3bb01_row3_col0, #T_3bb01_row3_col1, #T_3bb01_row3_col2, #T_3bb01_row3_col3, #T_3bb01_row3_col4, #T_3bb01_row3_col5, #T_3bb01_row3_col6, #T_3bb01_row3_col7, #T_3bb01_row4_col0, #T_3bb01_row4_col1, #T_3bb01_row4_col2, #T_3bb01_row4_col3, #T_3bb01_row4_col5, #T_3bb01_row4_col6, #T_3bb01_row4_col7, #T_3bb01_row5_col0, #T_3bb01_row5_col1, #T_3bb01_row5_col2, #T_3bb01_row5_col4, #T_3bb01_row5_col5, #T_3bb01_row5_col6, #T_3bb01_row5_col7, #T_3bb01_row6_col0, #T_3bb01_row6_col1, #T_3bb01_row6_col2, #T_3bb01_row6_col3, #T_3bb01_row6_col4, #T_3bb01_row6_col5, #T_3bb01_row6_col6, #T_3bb01_row6_col7, #T_3bb01_row7_col0, #T_3bb01_row7_col1, #T_3bb01_row7_col2, #T_3bb01_row7_col3, #T_3bb01_row7_col4, #T_3bb01_row7_col5, #T_3bb01_row7_col6, #T_3bb01_row7_col7, #T_3bb01_row8_col0, #T_3bb01_row8_col1, #T_3bb01_row8_col2, #T_3bb01_row8_col3, #T_3bb01_row8_col4, #T_3bb01_row8_col5, #T_3bb01_row8_col6, #T_3bb01_row8_col7, #T_3bb01_row9_col0, #T_3bb01_row9_col1, #T_3bb01_row9_col2, #T_3bb01_row9_col3, #T_3bb01_row9_col4, #T_3bb01_row9_col5, #T_3bb01_row9_col6, #T_3bb01_row9_col7, #T_3bb01_row10_col0, #T_3bb01_row10_col1, #T_3bb01_row10_col2, #T_3bb01_row10_col3, #T_3bb01_row10_col4, #T_3bb01_row10_col5, #T_3bb01_row10_col6, #T_3bb01_row10_col7, #T_3bb01_row11_col0, #T_3bb01_row11_col1, #T_3bb01_row11_col2, #T_3bb01_row11_col3, #T_3bb01_row11_col4, #T_3bb01_row11_col5, #T_3bb01_row11_col6, #T_3bb01_row11_col7, #T_3bb01_row12_col0, #T_3bb01_row12_col1, #T_3bb01_row12_col2, #T_3bb01_row12_col3, #T_3bb01_row12_col4, #T_3bb01_row12_col5, #T_3bb01_row12_col6, #T_3bb01_row12_col7, #T_3bb01_row13_col0, #T_3bb01_row13_col1, #T_3bb01_row13_col2, #T_3bb01_row13_col3, #T_3bb01_row13_col4, #T_3bb01_row13_col5, #T_3bb01_row13_col6, #T_3bb01_row13_col7 {
#   text-align: left;
# }
# #T_3bb01_row0_col1, #T_3bb01_row0_col2, #T_3bb01_row0_col6, #T_3bb01_row0_col7, #T_3bb01_row2_col5, #T_3bb01_row4_col4, #T_3bb01_row5_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3bb01_row0_col8, #T_3bb01_row2_col8, #T_3bb01_row3_col8, #T_3bb01_row4_col8, #T_3bb01_row5_col8, #T_3bb01_row6_col8, #T_3bb01_row7_col8, #T_3bb01_row8_col8, #T_3bb01_row9_col8, #T_3bb01_row10_col8, #T_3bb01_row11_col8, #T_3bb01_row12_col8, #T_3bb01_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3bb01_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3bb01_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bb01_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_3bb01_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3bb01_row0_col1" class="data row0 col1" >0.7838</td>
#       <td id="T_3bb01_row0_col2" class="data row0 col2" >0.8341</td>
#       <td id="T_3bb01_row0_col3" class="data row0 col3" >0.5378</td>
#       <td id="T_3bb01_row0_col4" class="data row0 col4" >0.7412</td>
#       <td id="T_3bb01_row0_col5" class="data row0 col5" >0.6231</td>
#       <td id="T_3bb01_row0_col6" class="data row0 col6" >0.4769</td>
#       <td id="T_3bb01_row0_col7" class="data row0 col7" >0.4891</td>
#       <td id="T_3bb01_row0_col8" class="data row0 col8" >0.7990</td>
#     </tr>
#     <tr>
#       <th id="T_3bb01_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_3bb01_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_3bb01_row1_col1" class="data row1 col1" >0.7828</td>
#       <td id="T_3bb01_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_3bb01_row1_col3" class="data row1 col3" >0.5272</td>
#       <td id="T_3bb01_row1_col4" class="data row1 col4" >0.7454</td>
#       <td id="T_3bb01_row1_col5" class="data row1 col5" >0.6173</td>
#       <td id="T_3bb01_row1_col6" class="data row1 col6" >0.4720</td>
#       <td id="T_3bb01_row1_col7" class="data row1 col7" >0.4859</td>
#       <td id="T_3bb01_row1_col8" class="data row1 col8" >0.6700</td>
#     </tr>
#     <tr>
#       <th id="T_3bb01_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_3bb01_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_3bb01_row2_col1" class="data row2 col1" >0.7788</td>
#       <td id="T_3bb01_row2_col2" class="data row2 col2" >0.8280</td>
#       <td id="T_3bb01_row2_col3" class="data row2 col3" >0.5581</td>
#       <td id="T_3bb01_row2_col4" class="data row2 col4" >0.7146</td>
#       <td id="T_3bb01_row2_col5" class="data row2 col5" >0.6263</td>
#       <td id="T_3bb01_row2_col6" class="data row2 col6" >0.4726</td>
#       <td id="T_3bb01_row2_col7" class="data row2 col7" >0.4802</td>
#       <td id="T_3bb01_row2_col8" class="data row2 col8" >1.7610</td>
#     </tr>
#     <tr>
#       <th id="T_3bb01_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_3bb01_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_3bb01_row3_col1" class="data row3 col1" >0.7671</td>
#       <td id="T_3bb01_row3_col2" class="data row3 col2" >0.8075</td>
#       <td id="T_3bb01_row3_col3" class="data row3 col3" >0.4549</td>
#       <td id="T_3bb01_row3_col4" class="data row3 col4" >0.7451</td>
#       <td id="T_3bb01_row3_col5" class="data row3 col5" >0.5644</td>
#       <td id="T_3bb01_row3_col6" class="data row3 col6" >0.4182</td>
#       <td id="T_3bb01_row3_col7" class="data row3 col7" >0.4420</td>
#       <td id="T_3bb01_row3_col8" class="data row3 col8" >0.7680</td>
#     </tr>
#     <tr>
#       <th id="T_3bb01_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_3bb01_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_3bb01_row4_col1" class="data row4 col1" >0.7575</td>
#       <td id="T_3bb01_row4_col2" class="data row4 col2" >0.8102</td>
#       <td id="T_3bb01_row4_col3" class="data row4 col3" >0.3763</td>
#       <td id="T_3bb01_row4_col4" class="data row4 col4" >0.7810</td>
#       <td id="T_3bb01_row4_col5" class="data row4 col5" >0.5076</td>
#       <td id="T_3bb01_row4_col6" class="data row4 col6" >0.3720</td>
#       <td id="T_3bb01_row4_col7" class="data row4 col7" >0.4157</td>
#       <td id="T_3bb01_row4_col8" class="data row4 col8" >1.8720</td>
#     </tr>
#     <tr>
#       <th id="T_3bb01_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_3bb01_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_3bb01_row5_col1" class="data row5 col1" >0.7570</td>
#       <td id="T_3bb01_row5_col2" class="data row5 col2" >0.8085</td>
#       <td id="T_3bb01_row5_col3" class="data row5 col3" >0.6127</td>
#       <td id="T_3bb01_row5_col4" class="data row5 col4" >0.6415</td>
#       <td id="T_3bb01_row5_col5" class="data row5 col5" >0.6262</td>
#       <td id="T_3bb01_row5_col6" class="data row5 col6" >0.4465</td>
#       <td id="T_3bb01_row5_col7" class="data row5 col7" >0.4472</td>
#       <td id="T_3bb01_row5_col8" class="data row5 col8" >0.7730</td>
#     </tr>
#     <tr>
#       <th id="T_3bb01_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_3bb01_row6_col0" class="data row6 col0" >Ada
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# CPU times: user 7.83 s, sys: 514 ms, total: 8.35 s
# Wall time: 3min 13s

# %%
predict_model(best);
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee2ad_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee2ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee2ad_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ee2ad_row0_col1" class="data row0 col1" >0.7839</td>
#       <td id="T_ee2ad_row0_col2" class="data row0 col2" >0.8378</td>
#       <td id="T_ee2ad_row0_col3" class="data row0 col3" >0.5510</td>
#       <td id="T_ee2ad_row0_col4" class="data row0 col4" >0.7328</td>
#       <td id="T_ee2ad_row0_col5" class="data row0 col5" >0.6290</td>
#       <td id="T_ee2ad_row0_col6" class="data row0 col6" >0.4809</td>
#       <td id="T_ee2ad_row0_col7" class="data row0 col7" >0.4906</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Anonymous Data

# %%
import pandas as pd
data_anonymous = pd.read_csv('adventure-works-bike-buying-synthetic_data.csv')

# %%
data_anonymous.shape
# Out:
# (16519, 24)

# %%
data_anonymous.head()
# Out:
#   CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0   0178b12f   NaN     Cathy     Ashley    Gordon    NaN
# 1   d7decf4a   NaN   Barbara        NaN    Watson    NaN
# 2   49e6dabd   NaN     Sarah  Elizabeth    Hanson    NaN
# 3   2776fb67   NaN   Russell    Caitlyn    Hanson    NaN
# 4   1d3fb317   NaN      Cory        NaN  Whitaker    NaN
#
#                      AddressLine1        AddressLine2           City  \
# 0       0521 Tammy Ramp Suite 678  8935 Burke Streets        Bobigny
# 1  3838 Catherine Field Suite 456  8935 Burke Streets    San Gabriel
# 2      1489 Grimes Lodge Apt. 391  8935 Burke Streets  National City
# 3                068 Knox Squares  8935 Burke Streets     Gold Coast
# 4               17475 Laura Court  8935 Burke Streets  Coffs Harbour
#
#   StateProvinceName  ...        Education    Occupation Gender MaritalStatus  \
# 0          55caead9  ...      High School        Manual      M             M
# 1          2e735720  ...  Partial College  Professional      M             M
# 2          f6ecfa6e  ...       Bachelors         Manual      F             S
# 3          b48517a3  ...       Bachelors         Manual      M             M
# 4          22cf0446  ...  Graduate Degree    Management      F             M
#
#   HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome TotalChildren  \
# 0             0               2                    0             2
# 1             1               2                    4             2
# 2             0               2                    0             0
# 3             0               1                    3             2
# 4             1               0                    0             3
#
#    YearlyIncome  BikeBuyer
# 0         14755          0
# 1         91955          0
# 2         13273          0
# 3        134081          0
# 4        121666          0
#
# [5 rows x 24 columns]

# %%
data_anonymous.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'BikeBuyer'],
#       dtype='object')

# %%
data_anonymous.dtypes
# Out:
# CustomerID              object
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# Suffix                  object
# AddressLine1            object
# AddressLine2            object
# City                    object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# PhoneNumber             object
# BirthDate               object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag            int64
# NumberCarsOwned          int64
# NumberChildrenAtHome     int64
# TotalChildren            int64
# YearlyIncome             int64
# BikeBuyer                int64
# dtype: object

# %%
data_anonymous.isnull().sum()
# Out:
# CustomerID                  0
# Title                   13575
# FirstName                   0
# MiddleName               5773
# LastName                    0
# Suffix                  14995
# AddressLine1                0
# AddressLine2                0
# City                        0
# StateProvinceName           0
# CountryRegionName           0
# PostalCode                  0
# PhoneNumber                 0
# BirthDate                   0
# Education                   0
# Occupation                  0
# Gender                      0
# MaritalStatus               0
# HomeOwnerFlag               0
# NumberCarsOwned             0
# NumberChildrenAtHome        0
# TotalChildren               0
# YearlyIncome                0
# BikeBuyer                   0
# dtype: int64

# %%
data_anonymous['BirthDate'] = pd.to_datetime(data_anonymous['BirthDate'])

# %%
from pycaret.classification import *
s = setup(data_anonymous, target = 'BikeBuyer', session_id = 123,
          ignore_features = ['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2', 'PhoneNumber'],
          numeric_features = ['TotalChildren', 'NumberChildrenAtHome', 'NumberCarsOwned', 'HomeOwnerFlag', 'YearlyIncome'],
          categorical_features = ['City', 'StateProvinceName', 'CountryRegionName', 'Education', 'Occupation', 'Gender', 'MaritalStatus', 'PostalCode'],
          date_features = ['BirthDate'],
          max_encoding_ohe=20)
# Out:
# <style type="text/css">
# #T_c4664_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c4664_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4664_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4664_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c4664_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4664_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c4664_row1_col1" class="data row1 col1" >BikeBuyer</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4664_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c4664_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4664_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c4664_row3_col1" class="data row3 col1" >(16519, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4664_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c4664_row4_col1" class="data row4 col1" >(16519, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c4664_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c4664_row5_col1" class="data row5 col1" >(11563, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c4664_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c4664_row6_col1" class="data row6 col1" >(4956, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c4664_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_c4664_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c4664_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_c4664_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c4664_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_c4664_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c4664_row10_col0" class="data row10 col0" >Date features</td>
#       <td id="T_c4664_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c4664_row11_col0" class="data row11 col0" >Categorical features</td>
#       <td id="T_c4664_row11_col1" class="data row11 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c4664_row12_col0" class="data row12 col0" >Rows with missing values</td>
#       <td id="T_c4664_row12_col1" class="data row12 col1" >93.1%</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c4664_row13_col0" class="data row13 col0" >Preprocess</td>
#       <td id="T_c4664_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c4664_row14_col0" class="data row14 col0" >Imputation type</td>
#       <td id="T_c4664_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c4664_row15_col0" class="data row15 col0" >Numeric imputation</td>
#       <td id="T_c4664_row15_col1" class="data row15 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c4664_row16_col0" class="data row16 col0" >Categorical imputation</td>
#       <td id="T_c4664_row16_col1" class="data row16 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c4664_row17_col0" class="data row17 col0" >Maximum one-hot encoding</td>
#       <td id="T_c4664_row17_col1" class="data row17 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c4664_row18_col0" class="data row18 col0" >Encoding method</td>
#       <td id="T_c4664_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c4664_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_c4664_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c4664_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_c4664_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c4664_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_c4664_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c4664_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_c4664_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c4664_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_c4664_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_c4664_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_c4664_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c4664_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_c4664_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_c4664_row25_col1" class="data row25 col1" >bb7e</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%time
best = compare_models()
# Out:
# <style type="text/css">
# #T_0ebd9_ th {
#   text-align: left;
# }
# #T_0ebd9_row0_col0, #T_0ebd9_row0_col3, #T_0ebd9_row0_col4, #T_0ebd9_row0_col5, #T_0ebd9_row0_col6, #T_0ebd9_row1_col0, #T_0ebd9_row1_col1, #T_0ebd9_row1_col2, #T_0ebd9_row1_col3, #T_0ebd9_row1_col5, #T_0ebd9_row1_col6, #T_0ebd9_row1_col7, #T_0ebd9_row2_col0, #T_0ebd9_row2_col1, #T_0ebd9_row2_col2, #T_0ebd9_row2_col3, #T_0ebd9_row2_col4, #T_0ebd9_row2_col5, #T_0ebd9_row2_col6, #T_0ebd9_row2_col7, #T_0ebd9_row3_col0, #T_0ebd9_row3_col1, #T_0ebd9_row3_col2, #T_0ebd9_row3_col3, #T_0ebd9_row3_col4, #T_0ebd9_row3_col5, #T_0ebd9_row3_col6, #T_0ebd9_row3_col7, #T_0ebd9_row4_col0, #T_0ebd9_row4_col1, #T_0ebd9_row4_col2, #T_0ebd9_row4_col4, #T_0ebd9_row4_col7, #T_0ebd9_row5_col0, #T_0ebd9_row5_col1, #T_0ebd9_row5_col2, #T_0ebd9_row5_col3, #T_0ebd9_row5_col4, #T_0ebd9_row5_col5, #T_0ebd9_row5_col6, #T_0ebd9_row5_col7, #T_0ebd9_row6_col0, #T_0ebd9_row6_col1, #T_0ebd9_row6_col2, #T_0ebd9_row6_col3, #T_0ebd9_row6_col4, #T_0ebd9_row6_col5, #T_0ebd9_row6_col6, #T_0ebd9_row6_col7, #T_0ebd9_row7_col0, #T_0ebd9_row7_col1, #T_0ebd9_row7_col2, #T_0ebd9_row7_col3, #T_0ebd9_row7_col4, #T_0ebd9_row7_col5, #T_0ebd9_row7_col6, #T_0ebd9_row7_col7, #T_0ebd9_row8_col0, #T_0ebd9_row8_col1, #T_0ebd9_row8_col2, #T_0ebd9_row8_col3, #T_0ebd9_row8_col4, #T_0ebd9_row8_col5, #T_0ebd9_row8_col6, #T_0ebd9_row8_col7, #T_0ebd9_row9_col0, #T_0ebd9_row9_col1, #T_0ebd9_row9_col2, #T_0ebd9_row9_col3, #T_0ebd9_row9_col4, #T_0ebd9_row9_col5, #T_0ebd9_row9_col6, #T_0ebd9_row9_col7, #T_0ebd9_row10_col0, #T_0ebd9_row10_col1, #T_0ebd9_row10_col2, #T_0ebd9_row10_col3, #T_0ebd9_row10_col4, #T_0ebd9_row10_col5, #T_0ebd9_row10_col6, #T_0ebd9_row10_col7, #T_0ebd9_row11_col0, #T_0ebd9_row11_col1, #T_0ebd9_row11_col2, #T_0ebd9_row11_col3, #T_0ebd9_row11_col4, #T_0ebd9_row11_col5, #T_0ebd9_row11_col6, #T_0ebd9_row11_col7, #T_0ebd9_row12_col0, #T_0ebd9_row12_col1, #T_0ebd9_row12_col2, #T_0ebd9_row12_col3, #T_0ebd9_row12_col4, #T_0ebd9_row12_col5, #T_0ebd9_row12_col6, #T_0ebd9_row12_col7, #T_0ebd9_row13_col0, #T_0ebd9_row13_col1, #T_0ebd9_row13_col2, #T_0ebd9_row13_col3, #T_0ebd9_row13_col4, #T_0ebd9_row13_col5, #T_0ebd9_row13_col6, #T_0ebd9_row13_col7 {
#   text-align: left;
# }
# #T_0ebd9_row0_col1, #T_0ebd9_row0_col2, #T_0ebd9_row0_col7, #T_0ebd9_row1_col4, #T_0ebd9_row4_col3, #T_0ebd9_row4_col5, #T_0ebd9_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0ebd9_row0_col8, #T_0ebd9_row2_col8, #T_0ebd9_row3_col8, #T_0ebd9_row4_col8, #T_0ebd9_row5_col8, #T_0ebd9_row6_col8, #T_0ebd9_row7_col8, #T_0ebd9_row8_col8, #T_0ebd9_row9_col8, #T_0ebd9_row10_col8, #T_0ebd9_row11_col8, #T_0ebd9_row12_col8, #T_0ebd9_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0ebd9_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0ebd9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ebd9_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_0ebd9_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0ebd9_row0_col1" class="data row0 col1" >0.7702</td>
#       <td id="T_0ebd9_row0_col2" class="data row0 col2" >0.7717</td>
#       <td id="T_0ebd9_row0_col3" class="data row0 col3" >0.3546</td>
#       <td id="T_0ebd9_row0_col4" class="data row0 col4" >0.6242</td>
#       <td id="T_0ebd9_row0_col5" class="data row0 col5" >0.4518</td>
#       <td id="T_0ebd9_row0_col6" class="data row0 col6" >0.3202</td>
#       <td id="T_0ebd9_row0_col7" class="data row0 col7" >0.3409</td>
#       <td id="T_0ebd9_row0_col8" class="data row0 col8" >0.8000</td>
#     </tr>
#     <tr>
#       <th id="T_0ebd9_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_0ebd9_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_0ebd9_row1_col1" class="data row1 col1" >0.7696</td>
#       <td id="T_0ebd9_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_0ebd9_row1_col3" class="data row1 col3" >0.3096</td>
#       <td id="T_0ebd9_row1_col4" class="data row1 col4" >0.6446</td>
#       <td id="T_0ebd9_row1_col5" class="data row1 col5" >0.4178</td>
#       <td id="T_0ebd9_row1_col6" class="data row1 col6" >0.2957</td>
#       <td id="T_0ebd9_row1_col7" class="data row1 col7" >0.3268</td>
#       <td id="T_0ebd9_row1_col8" class="data row1 col8" >0.6830</td>
#     </tr>
#     <tr>
#       <th id="T_0ebd9_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_0ebd9_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_0ebd9_row2_col1" class="data row2 col1" >0.7591</td>
#       <td id="T_0ebd9_row2_col2" class="data row2 col2" >0.7451</td>
#       <td id="T_0ebd9_row2_col3" class="data row2 col3" >0.3161</td>
#       <td id="T_0ebd9_row2_col4" class="data row2 col4" >0.5928</td>
#       <td id="T_0ebd9_row2_col5" class="data row2 col5" >0.4120</td>
#       <td id="T_0ebd9_row2_col6" class="data row2 col6" >0.2778</td>
#       <td id="T_0ebd9_row2_col7" class="data row2 col7" >0.2997</td>
#       <td id="T_0ebd9_row2_col8" class="data row2 col8" >1.8680</td>
#     </tr>
#     <tr>
#       <th id="T_0ebd9_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_0ebd9_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_0ebd9_row3_col1" class="data row3 col1" >0.7537</td>
#       <td id="T_0ebd9_row3_col2" class="data row3 col2" >0.7136</td>
#       <td id="T_0ebd9_row3_col3" class="data row3 col3" >0.3057</td>
#       <td id="T_0ebd9_row3_col4" class="data row3 col4" >0.5748</td>
#       <td id="T_0ebd9_row3_col5" class="data row3 col5" >0.3982</td>
#       <td id="T_0ebd9_row3_col6" class="data row3 col6" >0.2614</td>
#       <td id="T_0ebd9_row3_col7" class="data row3 col7" >0.2824</td>
#       <td id="T_0ebd9_row3_col8" class="data row3 col8" >0.7810</td>
#     </tr>
#     <tr>
#       <th id="T_0ebd9_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_0ebd9_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_0ebd9_row4_col1" class="data row4 col1" >0.7528</td>
#       <td id="T_0ebd9_row4_col2" class="data row4 col2" >0.7411</td>
#       <td id="T_0ebd9_row4_col3" class="data row4 col3" >0.4296</td>
#       <td id="T_0ebd9_row4_col4" class="data row4 col4" >0.5485</td>
#       <td id="T_0ebd9_row4_col5" class="data row4 col5" >0.4815</td>
#       <td id="T_0ebd9_row4_col6" class="data row4 col6" >0.3224</td>
#       <td id="T_0ebd9_row4_col7" class="data row4 col7" >0.3268</td>
#       <td id="T_0ebd9_row4_col8" class="data row4 col8" >0.7610</td>
#     </tr>
#     <tr>
#       <th id="T_0ebd9_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_0ebd9_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_0ebd9_row5_col1" class="data row5 col1" >0.7410</td>
#       <td id="T_0ebd9_row5_col2" class="data row5 col2" >0.7284</td>
#       <td id="T_0ebd9_row5_col3" class="data row5 col3" >0.2317</td>
#       <td id="T_0ebd9_row5_col4" class="data row5 col4" >0.5846</td>
#       <td id="T_0ebd9_row5_col5" class="data row5 col5" >0.3222</td>
#       <td id="T_0ebd9_row5_col6" class="data row5 col6" >0.1958</td>
#       <td id="T_0ebd9_row5_col7" class="data row5 col7" >0.2345</td>
#       <td id="T_0ebd9_row5_col8" class="data row5 col8" >1.9380</td>
#     </tr>
#     <tr>
#       <th id="T_0ebd9_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_0ebd9_row6_col0" class="data row6 col0" >Logis
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# CPU times: user 8.16 s, sys: 448 ms, total: 8.6 s
# Wall time: 3min 7s

# %%
predict_model(best);
# Out:
# <style type="text/css">
# </style>
# <table id="T_66f63_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66f63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66f63_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_66f63_row0_col1" class="data row0 col1" >0.7746</td>
#       <td id="T_66f63_row0_col2" class="data row0 col2" >0.7816</td>
#       <td id="T_66f63_row0_col3" class="data row0 col3" >0.3728</td>
#       <td id="T_66f63_row0_col4" class="data row0 col4" >0.6333</td>
#       <td id="T_66f63_row0_col5" class="data row0 col5" >0.4694</td>
#       <td id="T_66f63_row0_col6" class="data row0 col6" >0.3382</td>
#       <td id="T_66f63_row0_col7" class="data row0 col7" >0.3574</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('done')
# Out:
# done

# %%
tune_model(best, optimize = 'AUC', n_iter = 50)
# Out:
# <style type="text/css">
# #T_655e8_row10_col0, #T_655e8_row10_col1, #T_655e8_row10_col2, #T_655e8_row10_col3, #T_655e8_row10_col4, #T_655e8_row10_col5, #T_655e8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_655e8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_655e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_655e8_row0_col0" class="data row0 col0" >0.7701</td>
#       <td id="T_655e8_row0_col1" class="data row0 col1" >0.7706</td>
#       <td id="T_655e8_row0_col2" class="data row0 col2" >0.3333</td>
#       <td id="T_655e8_row0_col3" class="data row0 col3" >0.6319</td>
#       <td id="T_655e8_row0_col4" class="data row0 col4" >0.4364</td>
#       <td id="T_655e8_row0_col5" class="data row0 col5" >0.3090</td>
#       <td id="T_655e8_row0_col6" class="data row0 col6" >0.3339</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_655e8_row1_col0" class="data row1 col0" >0.7701</td>
#       <td id="T_655e8_row1_col1" class="data row1 col1" >0.7666</td>
#       <td id="T_655e8_row1_col2" class="data row1 col2" >0.3204</td>
#       <td id="T_655e8_row1_col3" class="data row1 col3" >0.6387</td>
#       <td id="T_655e8_row1_col4" class="data row1 col4" >0.4267</td>
#       <td id="T_655e8_row1_col5" class="data row1 col5" >0.3022</td>
#       <td id="T_655e8_row1_col6" class="data row1 col6" >0.3304</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_655e8_row2_col0" class="data row2 col0" >0.7701</td>
#       <td id="T_655e8_row2_col1" class="data row2 col1" >0.7742</td>
#       <td id="T_655e8_row2_col2" class="data row2 col2" >0.3548</td>
#       <td id="T_655e8_row2_col3" class="data row2 col3" >0.6250</td>
#       <td id="T_655e8_row2_col4" class="data row2 col4" >0.4527</td>
#       <td id="T_655e8_row2_col5" class="data row2 col5" >0.3209</td>
#       <td id="T_655e8_row2_col6" class="data row2 col6" >0.3415</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_655e8_row3_col0" class="data row3 col0" >0.7690</td>
#       <td id="T_655e8_row3_col1" class="data row3 col1" >0.7750</td>
#       <td id="T_655e8_row3_col2" class="data row3 col2" >0.3754</td>
#       <td id="T_655e8_row3_col3" class="data row3 col3" >0.6105</td>
#       <td id="T_655e8_row3_col4" class="data row3 col4" >0.4649</td>
#       <td id="T_655e8_row3_col5" class="data row3 col5" >0.3282</td>
#       <td id="T_655e8_row3_col6" class="data row3 col6" >0.3440</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_655e8_row4_col0" class="data row4 col0" >0.7734</td>
#       <td id="T_655e8_row4_col1" class="data row4 col1" >0.7839</td>
#       <td id="T_655e8_row4_col2" class="data row4 col2" >0.3560</td>
#       <td id="T_655e8_row4_col3" class="data row4 col3" >0.6358</td>
#       <td id="T_655e8_row4_col4" class="data row4 col4" >0.4564</td>
#       <td id="T_655e8_row4_col5" class="data row4 col5" >0.3274</td>
#       <td id="T_655e8_row4_col6" class="data row4 col6" >0.3494</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_655e8_row5_col0" class="data row5 col0" >0.7716</td>
#       <td id="T_655e8_row5_col1" class="data row5 col1" >0.7573</td>
#       <td id="T_655e8_row5_col2" class="data row5 col2" >0.3398</td>
#       <td id="T_655e8_row5_col3" class="data row5 col3" >0.6364</td>
#       <td id="T_655e8_row5_col4" class="data row5 col4" >0.4430</td>
#       <td id="T_655e8_row5_col5" class="data row5 col5" >0.3157</td>
#       <td id="T_655e8_row5_col6" class="data row5 col6" >0.3403</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_655e8_row6_col0" class="data row6 col0" >0.7647</td>
#       <td id="T_655e8_row6_col1" class="data row6 col1" >0.7656</td>
#       <td id="T_655e8_row6_col2" class="data row6 col2" >0.3657</td>
#       <td id="T_655e8_row6_col3" class="data row6 col3" >0.5979</td>
#       <td id="T_655e8_row6_col4" class="data row6 col4" >0.4538</td>
#       <td id="T_655e8_row6_col5" class="data row6 col5" >0.3148</td>
#       <td id="T_655e8_row6_col6" class="data row6 col6" >0.3302</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_655e8_row7_col0" class="data row7 col0" >0.7785</td>
#       <td id="T_655e8_row7_col1" class="data row7 col1" >0.7826</td>
#       <td id="T_655e8_row7_col2" class="data row7 col2" >0.3754</td>
#       <td id="T_655e8_row7_col3" class="data row7 col3" >0.6480</td>
#       <td id="T_655e8_row7_col4" class="data row7 col4" >0.4754</td>
#       <td id="T_655e8_row7_col5" class="data row7 col5" >0.3474</td>
#       <td id="T_655e8_row7_col6" class="data row7 col6" >0.3683</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_655e8_row8_col0" class="data row8 col0" >0.7708</td>
#       <td id="T_655e8_row8_col1" class="data row8 col1" >0.7809</td>
#       <td id="T_655e8_row8_col2" class="data row8 col2" >0.3786</td>
#       <td id="T_655e8_row8_col3" class="data row8 col3" >0.6158</td>
#       <td id="T_655e8_row8_col4" class="data row8 col4" >0.4689</td>
#       <td id="T_655e8_row8_col5" class="data row8 col5" >0.3332</td>
#       <td id="T_655e8_row8_col6" class="data row8 col6" >0.3492</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_655e8_row9_col0" class="data row9 col0" >0.7621</td>
#       <td id="T_655e8_row9_col1" class="data row9 col1" >0.7611</td>
#       <td id="T_655e8_row9_col2" class="data row9 col2" >0.3430</td>
#       <td id="T_655e8_row9_col3" class="data row9 col3" >0.5955</td>
#       <td id="T_655e8_row9_col4" class="data row9 col4" >0.4353</td>
#       <td id="T_655e8_row9_col5" class="data row9 col5" >0.2982</td>
#       <td id="T_655e8_row9_col6" class="data row9 col6" >0.3164</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_655e8_row10_col0" class="data row10 col0" >0.7700</td>
#       <td id="T_655e8_row10_col1" class="data row10 col1" >0.7718</td>
#       <td id="T_655e8_row10_col2" class="data row10 col2" >0.3543</td>
#       <td id="T_655e8_row10_col3" class="data row10 col3" >0.6236</td>
#       <td id="T_655e8_row10_col4" class="data row10 col4" >0.4514</td>
#       <td id="T_655e8_row10_col5" class="data row10 col5" >0.3197</td>
#       <td id="T_655e8_row10_col6" class="data row10 col6" >0.3404</td>
#     </tr>
#     <tr>
#       <th id="T_655e8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_655e8_row11_col0" class="data row11 col0" >0.0042</td>
#       <td id="T_655e8_row11_col1" class="data row11 col1" >0.0087</td>
#       <td id="T_655e8_row11_col2" class="data row11 col2" >0.0188</td>
#       <td id="T_655e8_row11_col3" class="data row11 col3" >0.0170</td>
#       <td id="T_655e8_row11_col4" class="data row11 col4" >0.0150</td>
#       <td id="T_655e8_row11_col5" class="data row11 col5" >0.0142</td>
#       <td id="T_655e8_row11_col6" class="data
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage='auto', solver='lsqr',
#                            store_covariance=False, tol=0.0001)
